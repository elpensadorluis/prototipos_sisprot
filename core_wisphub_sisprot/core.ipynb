# %%
# !python -m pip install requests pandas

# %%
import requests
import numpy as np
import pandas as pd
import json as json

# %%
# pd.options.display.max_rows
pd.options.display.max_columns = None

# %%
def peticion_pag(url, key):
    api_url_i = url
    b = ''
    while True:
        response2 = requests.get(api_url_i, headers=key)
        respuesta2 = response2.json()

        api_url_i = respuesta2['next']
        a = np.array(respuesta2['results'])
        if len(b) <= 0:
            b = a
        else:
            b = np.concatenate((a,b))
        # the below condition will tell
        # the loop to stop
        print(f"{len(b):4} de {str(respuesta2['count'])} : {len(b)/respuesta2['count']:.2%}")

        if len(b) >= respuesta2['count']:
            break

    return b

# %%
def peticion(url, key):

    response2 = requests.get(url, headers=key)
    respuesta2 = response2.json()

    b = np.array(respuesta2)

    # print(f"{len(b):4} de {str(respuesta2['count'])} : {len(b)/respuesta2['count']:.2%}")

    return b

# %%
def pedir_cliente_info(key, listas, n_clientes):
    clientes_cantidad = n_clientes 
    virgen = True
    b = []
    contador = 0
    for lista in listas:
        api_url = "https://api.wisphub.io/api/clientes/" + str(lista) + "/perfil/"
        response2 = requests.get(api_url, headers=key)
        respuesta2 = response2.json

        # api_url_i = respuesta2['next']
        b.append(respuesta2)  
        # if virgen:
        #     b = a
        #     virgen = False
        # else:
        #     b = np.concatenate((a,b))
        # the below condition will tell
        # the loop to stop
        contador += 1
        print(f"{str(contador:4)} de {str(clientes_cantidad)} : {contador/clientes_cantidad:.2%}")

    return b

# %% [markdown]
# # Clientes

# %% [markdown]
# ## Lista de Clientes

# %%
api_url = "https://api.wisphub.io/api/clientes/"
headers = {'Authorization': 'Api-Key iLxPUL95.91N2wfwoR6DvqFZQE3u5gbs4cWdZgnNk'}

# %%
clientes = peticion_pag(api_url, headers)
df_clientes = pd.json_normalize(clientes)
# Out:
#  300 de 2244 : 13.37%
#  600 de 2244 : 26.74%
#  900 de 2244 : 40.11%
# 1200 de 2244 : 53.48%
# 1500 de 2244 : 66.84%
# 1800 de 2244 : 80.21%
# 2100 de 2244 : 93.58%
# 2244 de 2244 : 100.00%

# %%
df_clientes = df_clientes.set_index('id_servicio')
print(df_clientes.count())
df_clientes.head(2)
# Out:
# usuario                      2244
# nombre                       2244
# email                        2244
# cedula                       2244
# direccion                    2244
# localidad                    2244
# ciudad                       2244
# telefono                     2244
# descuento                    2244
# saldo                        2244
# rfc                          2244
# informacion_adicional        2243
# notificacion_sms             2244
# aviso_pantalla               2244
# notificaciones_push          2244
# auto_activar_servicio        2244
# firewall                     2244
# servicio                     2244
# password_servicio            2244
# server_hotspot               2244
# ip                           2244
# ip_local                        0
# estado                       2244
# modelo_antena                   0
# password_cpe                 2244
# mac_cpe                      2244
# interfaz_lan                 2244
# modelo_router_wifi           2244
# ip_router_wifi                  0
# mac_router_wifi              2244
# usuario_router_wifi          2244
# password_router_wifi         2244
# ssid_router_wifi             2244
# password_ssid_router_wifi    2244
# comentarios                  2244
# coordenadas                  2244
# costo_instalacion            2244
# precio_plan                  2244
# forma_contratacion           2244
# sn_onu                       2244
# estado_facturas              2244
# fecha_instalacion            2244
# fecha_cancelacion               4
# fecha_corte                  2244
# ultimo_cambio                2244
# sectorial                       0
# plan_internet.id             2244
# plan_internet.nombre         2244
# zona.id                      2244
# zona.nombre                  2244
# router.id                    2244
# router.nombre                2244
# tecnico.id                   2243
# tecnico.nombre               2243
# tecnico                         0
# dtype: int64
#                                     usuario  \
# id_servicio
# 159           antoniov@sisprot-global-fiber
# 158          fernandot@sisprot-global-fiber
#
#                                          nombre                         email  \
# id_servicio
# 159          Antonio Cristiam Vendola Rodriguez    antoniovendola74@gmail.com
# 158           Fernando Alfredo Turmero Villegas  fernando_turmero@hotmail.com
#
#                 cedula                                          direccion  \
# id_servicio
# 159          V12361828  Calle 1 Casa Nro 12 Urb La Floresta Turmero Ed...
# 158          V12738318  Calle 3 Casa Nro E12 Urb La Floresta Turmero A...
#
#                localidad   ciudad    telefono descuento saldo          rfc  \
# id_servicio
# 159          La Floresta  Turmero  4124895306      0.00  0.00  V12361828-5
# 158          La Floresta  Turmero  4121753346      0.00  0.00  V12738318-5
#
#             informacion_adicional  notificacion_sms  aviso_pantalla  \
# id_servicio
# 159                   Residencial              True           False
# 158                   Residencial              True           False
#
#              notificaciones_push  auto_activar_servicio  firewall  \
# id_servicio
# 159                         True                   True      True
# 158                         True                   True      True
#
#                           servicio password_servicio server_hotspot  \
# id_servicio
# 159          LFL_Antonio_Rodriguez
# 158          LFL_Fernando_Villegas
#
#                       ip ip_local     estado modelo_antena password_cpe  \
# id_servicio
# 159          172.20.79.2     None     Activo          None
# 158          172.20.80.2     None  Cancelado          None
#
#             mac_cpe        interfaz_lan modelo_router_wifi ip_router_wifi  \
# id_servicio
# 159                  ether4_Balanceador          Tenda ac5           None
# 158                  ether4_Balanceador                              None
#
#                mac_router_wifi usuario_router_wifi password_router_wifi  \
# id_servicio
# 159          E8:48:B8:62:83:DE
# 158
#
#             ssid_router_wifi password_ssid_router_wifi  \
# id_servicio
# 159
# 158
#
#                                                    comentarios coordenadas  \
# id_servicio
# 159          <p>Plan B&aacute;sico</p>\r\n\r\n<p>GPON&nbsp;...
# 158                                  <p>Plan B&aacute;sico</p>
#
#             costo_instalacion precio_plan forma_contratacion        sn_onu  \
# id_servicio
# 159                                 25.00      -------------  TPLGB86283DE
# 158                                 25.00      -------------
#
#                estado_facturas    fecha_instalacion fecha_cancelacion  \
# id_servicio
# 159          Pendiente de Pago  07/30/2021 19:47:00              None
# 158          Pendiente de Pago  07/30/2021 19:45:00              None
#
#             fecha_corte        ultimo_cambio sectorial  plan_internet.id  \
# id_servicio
# 159            6/6/2023  04/14/2023 10:24:31      None             92189
# 158            6/6/2023  12/10/2022 14:19:00      None             92189
#
#             plan_internet.nombre  zona.id zona.nombre  router.id  \
# id_servicio
# 159          PLAN 80M N1 TURMERO    15818     Turmero      15811
# 158          PLAN 80M N1 TURMERO    15818     Turmero      15811
#
#             router.nombre  tecnico.id   tecnico.nombre  tecnico
# id_servicio
# 159               Turmero     82912.0    Elisaul Reyes      NaN
# 158               Turmero    132450.0  Edwar Hernandez      NaN

# %% [markdown]
# #

# %%
df_clientes.columns
# Out:
# Index(['usuario', 'nombre', 'email', 'cedula', 'direccion', 'localidad',
#        'ciudad', 'telefono', 'descuento', 'saldo', 'rfc',
#        'informacion_adicional', 'notificacion_sms', 'aviso_pantalla',
#        'notificaciones_push', 'auto_activar_servicio', 'firewall', 'servicio',
#        'password_servicio', 'server_hotspot', 'ip', 'ip_local', 'estado',
#        'modelo_antena', 'password_cpe', 'mac_cpe', 'interfaz_lan',
#        'modelo_router_wifi', 'ip_router_wifi', 'mac_router_wifi',
#        'usuario_router_wifi', 'password_router_wifi', 'ssid_router_wifi',
#        'password_ssid_router_wifi', 'comentarios', 'coordenadas',
#        'costo_instalacion', 'precio_plan', 'forma_contratacion', 'sn_onu',
#        'estado_facturas', 'fecha_instalacion', 'fecha_cancelacion',
#        'fecha_corte', 'ultimo_cambio', 'sectorial', 'plan_internet.id',
#        'plan_internet.nombre', 'zona.id', 'zona.nombre', 'router.id',
#        'router.nombre', 'tecnico.id', 'tecnico.nombre', 'tecnico'],
#       dtype='object')

# %%
df_clientes.dtypes
# Out:
# usuario                       object
# nombre                        object
# email                         object
# cedula                        object
# direccion                     object
# localidad                     object
# ciudad                        object
# telefono                      object
# descuento                     object
# saldo                         object
# rfc                           object
# informacion_adicional         object
# notificacion_sms                bool
# aviso_pantalla                  bool
# notificaciones_push             bool
# auto_activar_servicio           bool
# firewall                        bool
# servicio                      object
# password_servicio             object
# server_hotspot                object
# ip                            object
# ip_local                      object
# estado                        object
# modelo_antena                 object
# password_cpe                  object
# mac_cpe                       object
# interfaz_lan                  object
# modelo_router_wifi            object
# ip_router_wifi                object
# mac_router_wifi               object
# usuario_router_wifi           object
# password_router_wifi          object
# ssid_router_wifi              object
# password_ssid_router_wifi     object
# comentarios                   object
# coordenadas                   object
# costo_instalacion             object
# precio_plan                   object
# forma_contratacion            object
# sn_onu                        object
# estado_facturas               object
# fecha_instalacion             object
# fecha_cancelacion             object
# fecha_corte                   object
# ultimo_cambio                 object
# sectorial                     object
# plan_internet.id               int64
# plan_internet.nombre          object
# zona.id                        int64
# zona.nombre                   object
# router.id                      int64
# router.nombre                 object
# tecnico.id                   float64
# tecnico.nombre                object
# tecnico                      float64
# dtype: object

# %% [markdown]
# ## Clientes: Información adicional

# %%
# Obtener lista de id_servicio en variable
# lista_clientes_id = df_clientes['index'].tolist()
lista_clientes_id = df_clientes.index
len(lista_clientes_id)

# %%
print(lista_clientes_id[0])

# %%
id_servicio = 158
api_url = "https://api.wisphub.io/api/clientes/" + str(id_servicio) + "/perfil/"
print(api_url)

# %%
lista_clientes_id = df_clientes.index
clientes_cantidad = len(lista_clientes_id)
cliente_info = pedir_cliente_info(headers, lista_clientes_id, clientes_cantidad)

response2 = requests.get(api_url, headers=headers)
respuesta2 = response2.json()
df_cliente_info = pd.json_normalize(respuesta2)
df_cliente_info.head(2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[39], line 2
#       1 lista_clientes_id = df_clientes.index
# ----> 2 cliente_info = pedir_cliente_info(headers, lista_clientes_id)
#       4 response2 = requests.get(api_url, headers=headers)
#       5 respuesta2 = response2.json()
#
# Cell In[38], line 6, in pedir_cliente_info(key, listas)
#       4 for lista in listas:
#       5     api_url = "https://api.wisphub.io/api/clientes/" + str(lista) + "/perfil/"
# ----> 6     response2 = requests.get(api_url, headers=key)
#       7     respuesta2 = response2.json
#       9     # api_url_i = respuesta2['next']
#
# File ~/anaconda3/lib/python3.10/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/anaconda3/lib/python3.10/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/anaconda3/lib/python3.10/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     384 # Trigger any extra validation we need to do.
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#     389     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:1042, in HTTPSConnectionPool._validate_conn(self, conn)
#    1040 # Force connect early to allow us to validate the connection.
#    1041 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042     conn.connect()
#    1044 if not conn.is_verified:
#    1045     warnings.warn(
#    1046         (
#    1047             "Unverified HTTPS request is being made to host '%s'. "
#    (...)
#    1052         InsecureRequestWarning,
#    1053     )
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/connection.py:414, in HTTPSConnection.connect(self)
#     405 if (
#     406     not self.ca_certs
#     407     and not self.ca_cert_dir
#    (...)
#     410     and hasattr(context, "load_default_certs")
#     411 ):
#     412     context.load_default_certs()
# --> 414 self.sock = ssl_wrap_socket(
#     415     sock=conn,
#     416     keyfile=self.key_file,
#     417     certfile=self.cert_file,
#     418     key_password=self.key_password,
#     419     ca_certs=self.ca_certs,
#     420     ca_cert_dir=self.ca_cert_dir,
#     421     ca_cert_data=self.ca_cert_data,
#     422     server_hostname=server_hostname,
#     423     ssl_context=context,
#     424     tls_in_tls=tls_in_tls,
#     425 )
#     427 # If we're using all defaults and the connection
#     428 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     429 # for the host.
#     430 if (
#     431     default_ssl_context
#     432     and self.ssl_version is None
#     433     and hasattr(self.sock, "version")
#     434     and self.sock.version() in {"TLSv1", "TLSv1.1"}
#     435 ):
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/util/ssl_.py:449, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     437     warnings.warn(
#     438         "An HTTPS request has been made, but the SNI (Server Name "
#     439         "Indication) extension to TLS is not available on this platform. "
#    (...)
#     445         SNIMissingWarning,
#     446     )
#     448 if send_sni:
# --> 449     ssl_sock = _ssl_wrap_socket_impl(
#     450         sock, context, tls_in_tls, server_hostname=server_hostname
#     451     )
#     452 else:
#     453     ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls)
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/util/ssl_.py:493, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     490     return SSLTransport(sock, ssl_context, server_hostname)
#     492 if server_hostname:
# --> 493     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494 else:
#     495     return ssl_context.wrap_socket(sock)
#
# File ~/anaconda3/lib/python3.10/ssl.py:513, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     507 def wrap_socket(self, sock, server_side=False,
#     508                 do_handshake_on_connect=True,
#     509                 suppress_ragged_eofs=True,
#     510                 server_hostname=None, session=None):
#     511     # SSLSocket class handles server_hostname encoding before it calls
#     512     # ctx._wrap_socket()
# --> 513     return self.sslsocket_class._create(
#     514         sock=sock,
#     515         server_side=server_side,
#     516         do_handshake_on_connect=do_handshake_on_connect,
#     517         suppress_ragged_eofs=suppress_ragged_eofs,
#     518         server_hostname=server_hostname,
#     519         context=self,
#     520         session=session
#     521     )
#
# File ~/anaconda3/lib/python3.10/ssl.py:1071, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1068         if timeout == 0.0:
#    1069             # non-blocking
#    1070             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1071         self.do_handshake()
#    1072 except (OSError, ValueError):
#    1073     self.close()
#
# File ~/anaconda3/lib/python3.10/ssl.py:1342, in SSLSocket.do_handshake(self, block)
#    1340     if timeout == 0.0 and block:
#    1341         self.settimeout(None)
# -> 1342     self._sslobj.do_handshake()
#    1343 finally:
#    1344     self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
df_cliente_info.dtypes

# %% [markdown]
# # Lista de Zonas

# %%
api_url = "https://api.wisphub.io/api/zonas/"

zonas = peticion_pag(api_url, headers)

df_zonas = pd.json_normalize(zonas)

df_zonas = df_zonas.set_index('id')
df_zonas.head(2)

# %%
df_zonas.columns

# %%
df_zonas.dtypes
